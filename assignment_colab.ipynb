# %% [markdown]
# <a href="https://colab.research.google.com/github/Anson2Leung/Anson2Leung.github.io/blob/main/assignment_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
# !git clone https://github.com/Anson2Leung/ece405-assignment1-basics.git
# Out:
# Cloning into 'ece405-assignment1-basics'...
# remote: Enumerating objects: 465, done.
# remote: Counting objects: 100% (465/465), done.
# remote: Compressing objects: 100% (207/207), done.
# remote: Total 465 (delta 241), reused 461 (delta 240), pack-reused 0 (from 0)
# Receiving objects: 100% (465/465), 22.46 MiB | 29.34 MiB/s, done.
# Resolving deltas: 100% (241/241), done.

# %%
# Install uv
# !curl -LsSf https://astral.sh/uv/install.sh | sh

# Add uv to the system path so you can use it directly
import os
os.environ['PATH'] = f"{os.path.expanduser('~/.cargo/bin')}:{os.environ['PATH']}"
# Out:
# downloading uv 0.9.28 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
# %cd ece405-assignment1-basics

# !uv pip install -r requirements.txt --system
# !pip install "numpy<2.0" jaxtyping typeguard langsmith
# Out:
# /content/ece405-assignment1-basics
# Using Python 3.12.12 environment at: /usr
# Audited 3 packages in 110ms
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.12/dist-packages (1.26.4)
# Requirement already satisfied: jaxtyping in /usr/local/lib/python3.12/dist-packages (0.3.7)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.12/dist-packages (4.4.4)
# Requirement already satisfied: langsmith in /usr/local/lib/python3.12/dist-packages (0.6.6)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from jaxtyping) (0.1.7)
# Requirement already satisfied: typing_extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from typeguard) (4.15.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith) (3.11.5)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.12/dist-packages (from langsmith) (25.0)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langsmith) (2.12.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith) (2.32.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langsmith) (0.14.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith) (0.25.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->langsmith) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->langsmith) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->langsmith) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith) (2.5.0)

# %% [markdown]
# # Test run

# %%
# !pytest tests/test_train_bpe.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0
# rootdir: /content/ece405-assignment1-basics
# configfile: pytest.ini
# plugins: jaxtyping-0.3.7, anyio-4.12.1, typeguard-4.4.4, langsmith-0.6.6
# collected 3 items
#
# tests/test_train_bpe.py::test_train_bpe_speed PASSED                     [ 33%]
# tests/test_train_bpe.py::test_train_bpe PASSED                           [ 66%]
# tests/test_train_bpe.py::test_train_bpe_special_tokens FAILED            [100%]
#
# =================================== FAILURES ===================================
# ________________________ test_train_bpe_special_tokens _________________________
#
# snapshot = <tests.conftest.Snapshot object at 0x7dcb42290d10>
#
#     def test_train_bpe_special_tokens(snapshot):
#         """
#         Ensure that the special tokens are added to the vocabulary and not
#         merged with other tokens.
#         """
#         input_path = FIXTURES_PATH / "tinystories_sample_5M.txt"
#         vocab, merges = run_train_bpe(
#             input_path=input_path,
#             vocab_size=1000,
#             special_tokens=["<|endoftext|>"],
#         )
#
#         # Check that the special token is not in the vocab
#         vocabs_without_specials = [word for word in vocab.values() if word != b"<|endoftext|>"]
#         for word_bytes in vocabs_without_specials:
#             assert b"<|" not in word_bytes
#
# >       snapshot.assert_match(
#             {
#                 "vocab_keys": set(vocab.keys()),
#                 "vocab_values": set(vocab.values()),
#                 "merges": merges,
#             },
#         )
#
# tests/test_train_bpe.py:82:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <tests.conftest.Snapshot object at 0x7dcb42290d10>
# actual = {'merges': [(b'h', b'e'), (b' ', b't'), (b' ', b'a'), (b' ', b's'), (b' ', b'w'), (b'n', b'd'), ...], 'vocab_keys': {0, 1, 2, 3, 4, 5, ...}, 'vocab_values': {b'\x00', b'\x01', b'\x02', b'\x03', b'\x04', b'\x05', ...}}
# test_name = 'test_train_bpe_special_tokens', force_update = False
#
#     def assert_match(
#         self,
#         actual: _A | dict[str, _A],
#         test_name: str | type[DEFAULT] = DEFAULT,
#         force_update: bool | type[DEFAULT] = DEFAULT,
#     ):
#         """
#         Assert that the actual data matches the snapshot.
#         Args:
#             actual: Single object or dictionary of named objects
#             test_name: The name of the test (used for the snapshot file)
#             force_update: If True, update the snapshot instead of comparing
#         """
#
#         if force_update is DEFAULT:
#             force_update = self.default_force_update
#         if test_name is DEFAULT:
#             assert self.default_test_name is not None, "Test name must be provided or set as default"
#             test_name = self.default_test_name
#
#         snapshot_path = self._get_snapshot_path(test_name)
#
#         # Load the snapshot
#         with open(snapshot_path, "rb") as f:
#             expected_data = pickle.load(f)
#
#         if isinstance(actual, dict):
#             for key in actual:
#                 if key not in expected_data:
#                     raise AssertionError(f"Key '{key}' not found in snapshot for {test_name}")
# >               assert actual[key] == expected_data[key], (
#                     f"Data for key '{key}' does not match snapshot for {test_name}"
#                 )
# E               AssertionError: Data for key 'vocab_values' does not match snapshot for test_train_bpe_special_tokens
# E               assert {b'\x00', b'\... b'\x05', ...} == {b'\x00', b'\... b'\x05', ...}
# E
# E                 Extra items in the left set:
# E                 b' stay'
# E                 b' mad'
# E                 b'rel'
# E                 b'est'
# E                 b'ream'...
# E
# E                 ...Full output truncated (1105 lines hidden), use '-vv' to show
#
# tests/conftest.py:146: AssertionError
# ----------------------------- Captured stdout call -----------------------------
# Dataset:  /content/ece405-assignment1-basics/tests/fixtures/tinystories_sample_5M.txt
# Number of processes requested:  2
# Special tokens as bytes:  [b'<|endoftext|>']
# Total number of tasks to complete:  1
# Pre-tokenization complete. Unique pre-tokens: 6412
# Number of merges to perform:  743
# Pre-tokenize time complete in 0.78s
# Initialization time complete in 0.03s
# BPE Merges complete in 0.40s
# Total training time: 1.22s
# Total memory used: 3.65 MB
# ----------------------------- Captured stderr call -----------------------------
# Merging Vocab: 100%|██████████| 743/743 [00:00<00:00, 1862.58it/s]
# =============================== warnings summary ===============================
# tests/adapters.py:303
#   /content/ece405-assignment1-basics/tests/adapters.py:303: SyntaxWarning: invalid escape sequence '\T'
#     rope_theta (float): The RoPE $\Theta$ parameter.
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# =========================== short test summary info ============================
# FAILED tests/test_train_bpe.py::test_train_bpe_special_tokens - AssertionError: Data for key 'vocab_values' does not match snapshot for tes...
# ==================== 1 failed, 2 passed, 1 warning in 2.05s ====================

# %% [markdown]
# # Problem (train_bpe_tinystories): BPE Training on TinyStories (2 points)

# %%
# %cd ..
# %mkdir -p data
# %cd data

# !wget https://huggingface.co/datasets/roneneldan/TinyStories/resolve/main/TinyStoriesV2-GPT4-train.txt
# !wget https://huggingface.co/datasets/roneneldan/TinyStories/resolve/main/TinyStoriesV2-GPT4-valid.txt

# !wget https://huggingface.co/datasets/stanford-cs336/owt-sample/resolve/main/owt_train.txt.gz
# !gunzip owt_train.txt.gz
# !wget https://huggingface.co/datasets/stanford-cs336/owt-sample/resolve/main/owt_valid.txt.gz
# !gunzip owt_valid.txt.gz

# %cd ..
# %cd ece405-assignment1-basics
# Out:
# /content
# /content/data
# --2026-02-03 04:19:49--  https://huggingface.co/datasets/roneneldan/TinyStories/resolve/main/TinyStoriesV2-GPT4-train.txt
# Resolving huggingface.co (huggingface.co)... 3.167.112.25, 3.167.112.38, 3.167.112.45, ...
# Connecting to huggingface.co (huggingface.co)|3.167.112.25|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.gcp.cdn.hf.co/xet-bridge-us/645e8da96320b0efe40ade7a/02e40cc51c59a4bc6c51bd7bc9acda4316e208745be060558eaf500cd14e9f96?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27TinyStoriesV2-GPT4-train.txt%3B+filename%3D%22TinyStoriesV2-GPT4-train.txt%22%3B&response-content-type=text%2Fplain&Expires=1770095990&Policy=&Signature=k2sDxZ9-z89mSPsj2LxXoDh5xE1FrkM2de%7EIz8Fl7x3T8c1ugFontZkvmNxQ28LCBjLVxJfZaWRdYBI8MRF862myShTw9BKhsMinrOrBdGyYqiPHpM74WwcWWlvTnPwJQ5lBRkowSV8j0IN5W-lraNiN1UmyFfvczR%7EseRkAZ9Wd9FlBTVeLO0hftfP37f4cfxMJUU5syDBEFv2sifLrxAeRv1snBYvZ3O77sD%7Emh0AC05qfAISO1K5RVGE44uzHFOkZYGdBfcJs9xSoqoxks-Dq%7EJLCSYOdrvAn0rF-q1uj%7EML0RVPpFW9O4TQ7i6Yrg3sycpwjQCxEwEefQeDXYQ__&Key-Pair-Id=KJLH8B0YWU4Y8M [following]
# --2026-02-03 04:19:50--  https://us.gcp.cdn.hf.co/xet-bridge-us/645e8da96320b0efe40ade7a/02e40cc51c59a4bc6c51bd7bc9acda4316e208745be060558eaf500cd14e9f96?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27TinyStoriesV2-GPT4-train.txt%3B+filename%3D%22TinyStoriesV2-GPT4-train.txt%22%3B&response-content-type=text%2Fplain&Expires=1770095990&Policy=&Signature=k2sDxZ9-z89mSPsj2LxXoDh5xE1FrkM2de%7EIz8Fl7x3T8c1ugFontZkvmNxQ28LCBjLVxJfZaWRdYBI8MRF862myShTw9BKhsMinrOrBdGyYqiPHpM74WwcWWlvTnPwJQ5lBRkowSV8j0IN5W-lraNiN1UmyFfvczR%7EseRkAZ9Wd9FlBTVeLO0hftfP37f4cfxMJUU5syDBEFv2sifLrxAeRv1snBYvZ3O77sD%7Emh0AC05qfAISO1K5RVGE44uzHFOkZYGdBfcJs9xSoqoxks-Dq%7EJLCSYOdrvAn0rF-q1uj%7EML0RVPpFW9O4TQ7i6Yrg3sycpwjQCxEwEefQeDXYQ__&Key-Pair-Id=KJLH8B0YWU4Y8M
# Resolving us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)... 34.120.165.110
# Connecting to us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)|34.120.165.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2227753162 (2.1G) [text/plain]
# Saving to: ‘TinyStoriesV2-GPT4-train.txt’
#
# TinyStoriesV2-GPT4- 100%[===================>]   2.07G  81.3MB/s    in 28s
#
# 2026-02-03 04:20:18 (75.3 MB/s) - ‘TinyStoriesV2-GPT4-train.txt’ saved [2227753162/2227753162]
#
# --2026-02-03 04:20:18--  https://huggingface.co/datasets/roneneldan/TinyStories/resolve/main/TinyStoriesV2-GPT4-valid.txt
# Resolving huggingface.co (huggingface.co)... 3.167.112.45, 3.167.112.38, 3.167.112.25, ...
# Connecting to huggingface.co (huggingface.co)|3.167.112.45|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.gcp.cdn.hf.co/xet-bridge-us
response-content-disposition=inline%3B+filename*%3DUTF-8%27%27owt_valid.txt.gz%3B+filename%3D%22owt_valid.txt.gz%22%3B&response-content-type=application%2Fgzip&Expires=1770096233&Policy=&Signature=AfYnktKz%7EU5mjQ5gQ81O5Pl0onyxqeTAaB5EuqMaPaYKnJGorocNzqaX2WJJ7aVv5vOiKpBAw3tm3JYM61xZlnpSZyk5hR0WScHJGsfXY%7EFfCm8xeOMR4WFM0lHWQsaa38XV68PEb5TRBFlpGP9D8NyTtaNLDKeudJuI-NzaAyl-hY-v691d2BLNDs7QAb1frki4fSJ2x1-7jnv4lpbGzmdNmA8nFbOF7CFMyoepXKYrQs3IDVhXxSr8CZR4S1HL%7EkfLU0V4rU8Xkj8xGVm6i2NSEthymfS%7ERcQbcxY0HMhbxU33HfcJ6ZFJYpn4KOm57KjUDWcRPLGSbvhVbF8Q2w__&Key-Pair-Id=KJLH8B0YWU4Y8M [following]
# --2026-02-03 04:23:53--  https://us.gcp.cdn.hf.co/xet-bridge-us/660add462617cc957fd1bc02/dab4f6880340d5aaa3c404d5f7e4750e145cff7454bf9731eee7f633775cf8ab?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27owt_valid.txt.gz%3B+filename%3D%22owt_valid.txt.gz%22%3B&response-content-type=application%2Fgzip&Expires=1770096233&Policy=&Signature=AfYnktKz%7EU5mjQ5gQ81O5Pl0onyxqeTAaB5EuqMaPaYKnJGorocNzqaX2WJJ7aVv5vOiKpBAw3tm3JYM61xZlnpSZyk5hR0WScHJGsfXY%7EFfCm8xeOMR4WFM0lHWQsaa38XV68PEb5TRBFlpGP9D8NyTtaNLDKeudJuI-NzaAyl-hY-v691d2BLNDs7QAb1frki4fSJ2x1-7jnv4lpbGzmdNmA8nFbOF7CFMyoepXKYrQs3IDVhXxSr8CZR4S1HL%7EkfLU0V4rU8Xkj8xGVm6i2NSEthymfS%7ERcQbcxY0HMhbxU33HfcJ6ZFJYpn4KOm57KjUDWcRPLGSbvhVbF8Q2w__&Key-Pair-Id=KJLH8B0YWU4Y8M
# Resolving us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)... 34.120.165.110
# Connecting to us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)|34.120.165.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 111785382 (107M) [application/gzip]
# Saving to: ‘owt_valid.txt.gz’
#
# owt_valid.txt.gz    100%[===================>] 106.61M  47.9MB/s    in 2.2s
#
# 2026-02-03 04:23:56 (47.9 MB/s) - ‘owt_valid.txt.gz’ saved [111785382/111785382]
#
# /content
# /content/ece405-assignment1-basics

# %%
import sys
import os
import json

# 1. Ensure the script is in the path
# %cd /content/ece405-assignment1-basics
sys.path.append('/content/ece405-assignment1-basics/assignment_files')
from bpe_tokenizer import train_bpe, save_vocab, save_merges

# 2. Configuration
INPUT_PATH = "/content/data/TinyStoriesV2-GPT4-train.txt"
VOCAB_SIZE = 10000
SPECIAL_TOKENS = ["<|endoftext|>"]

# 3. Execution
# We call the function directly. Your code already handles the timing and memory printing.
vocab, merges = train_bpe(INPUT_PATH, VOCAB_SIZE, SPECIAL_TOKENS)

# 4. Serialization
save_vocab(vocab, "vocab.json")
save_merges(merges, "merges.txt")
# Out:
# /content/ece405-assignment1-basics
# Dataset:  /content/data/TinyStoriesV2-GPT4-train.txt
# Number of processes requested:  2
# Special tokens as bytes:  [b'<|endoftext|>']
# Total number of tasks to complete:  1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/ece405-assignment1-basics/assignment_files/bpe_tokenizer.py in get_token_counts(file_path, procs, special_tokens)
#     136         # starmap due to how the parameters are accepted in pre_tokenize_chunk
# --> 137         all_counts = pool.starmap(pre_tokenize_chunk, tasks)
#     138
#
# /usr/lib/python3.12/multiprocessing/pool.py in starmap(self, func, iterable, chunksize)
#     374         '''
# --> 375         return self._map_async(func, iterable, starmapstar, chunksize).get()
#     376
#
# /usr/lib/python3.12/multiprocessing/pool.py in get(self, timeout)
#     767     def get(self, timeout=None):
# --> 768         self.wait(timeout)
#     769         if not self.ready():
#
# /usr/lib/python3.12/multiprocessing/pool.py in wait(self, timeout)
#     764     def wait(self, timeout=None):
# --> 765         self._event.wait(timeout)
#     766
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     654             if not signaled:
# --> 655                 signaled = self._cond.wait(timeout)
#     656             return signaled
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     354             if timeout is None:
# --> 355                 waiter.acquire()
#     356                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3783886648.py in <cell line: 0>()
#      15 # 3. Execution
#      16 # We call the function directly. Your code already handles the timing and memory printing.
# ---> 17 vocab, merges = train_bpe(INPUT_PATH, VOCAB_SIZE, SPECIAL_TOKENS)
#      18
#      19 # 4. Serialization
#
# /content/ece405-assignment1-basics/assignment_files/bpe_tokenizer.py in train_bpe(input_path, vocab_size, special_tokens)
#     166     # Pretokenize and Count tokens
#     167     procs = multiprocessing.cpu_count()
# --> 168     token_counts = get_token_counts(input_path, procs, special_tokens)
#     169     pre_tokenize_time = time.perf_counter()
#     170
#
# /content/ece405-assignment1-basics/assignment_files/bpe_tokenizer.py in get_token_counts(file_path, procs, special_tokens)
#     133     print('Total number of tasks to complete: ', len(tasks))
#     134     num_workers = min(len(tasks), procs)
# --> 135     with multiprocessing.Pool(processes=num_workers) as pool:
#     136         # starmap due to how the parameters are accepted in pre_tokenize_chunk
#     137         all_counts = pool.starmap(pre_tokenize_chunk, tasks)
#
# /usr/lib/python3.12/multiprocessing/pool.py in __exit__(self, exc_type, exc_val, exc_tb)
#     737
#     738     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 739         self.terminate()
#     740
#     741 #
#
# /usr/lib/python3.12/multiprocessing/pool.py in terminate(self)
#     655         util.debug('terminating pool')
#     656         self._state = TERMINATE
# --> 657         self._terminate()
#     658
#     659     def join(self):
#
# /usr/lib/python3.12/multiprocessing/util.py in __call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     225                 sub_debug('finalizer calling %s with args %s and kwargs %s',
#     226                           self._callback, self._args, self._kwargs)
# --> 227                 res = self._callback(*self._args, **self._kwargs)
#     228             self._weakref = self._callback = self._args = \
#     229                             self._kwargs = self._key = None
#
# /usr/lib/python3.12/multiprocessing/pool.py in _terminate_pool(cls, taskqueue, inqueue, outqueue, pool, change_notifier, worker_handler, task_handler, result_handler, cache)
#     730                     # worker has not yet exited
#     731                     util.debug('cleaning up worker %d' % p.pid)
# --> 732                     p.join()
#     733
#     734     def __enter__(self):
#
# /usr/lib/python3.12/multiprocessing/process.py in join(self, timeout)
#     147         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148         assert self._popen is not None, 'can only join a started process'
# --> 149         res = self._popen.wait(timeout)
#     150         if res is not None:
#     151             _children.discard(self)
#
# /usr/lib/python3.12/multiprocessing/popen_fork.py in wait(self, timeout)
#      41                     return None
#      42             # This shouldn't block if wait() returned successfully.
# ---> 43             return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      44         return self.returncode
#      45
#
# /usr/lib/python3.12/multiprocessing/popen_fork.py in poll(self, flag)
#      25         if self.returncode is None:
#      26             try:
# ---> 27                 pid, sts = os.waitpid(self.pid, flag)
#      28             except OSError:
#      29                 # Child process not yet created. See #1731717
#
# KeyboardInterrupt:

# %%
# Analysis
def get_decoded_string(token_bytes):
    return token_bytes.decode('utf-8', errors='ignore')

# Find the longest token in the vocabulary
longest_token_id = max(vocab, key=lambda k: len(get_decoded_string(vocab[k])))
longest_token_bytes = vocab[longest_token_id]
longest_text = get_decoded_string(longest_token_bytes)

print(f"--- Analysis Results ---")
print(f"Longest Token ID: {longest_token_id}")
print(f"Longest Token Text: '{longest_text}'")
print(f"Character Length: {len(longest_text)}")
